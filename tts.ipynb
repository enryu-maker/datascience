# %%
# !git clone https://github.com/neonbjb/tortoise-tts.git
# Out:
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1710, done.
# remote: Counting objects: 100% (632/632), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 1710 (delta 521), reused 510 (delta 465), pack-reused 1078
# Receiving objects: 100% (1710/1710), 54.08 MiB | 29.69 MiB/s, done.
# Resolving deltas: 100% (752/752), done.

# %%
# !pip install deepspeed
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 836.6/836.6 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for deepspeed: filename=deepspeed-0.10.0-py3-none-any.whl size=877453 sha256=83d4bd3299d1be369fe2774ad6147e5452746806e2263bdda5f28068afba3c52
#   Stored in directory: /root/.cache/pip/wheels/20/7b/3f/2807682bad2fba40ed888e6309597a5fda545ab30964c835aa
# Successfully built deepspeed
# ...

# %%
# %cd tortoise-tts
# !python setup.py install
# Out:
# /content/tortoise-tts
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# %mv /content/*.wav /content/tortoise-tts/tortoise/voices/tate
# Out:
# mv: cannot stat '/content/*.wav': No such file or directory

# %%
"Programming is an art form of logic and creativity, where lines of code come alive to shape the digital world we inhabit. It requires dedication, discipline, and a thirst for knowledge. Every keystroke is a brushstroke, meticulously crafting intricate solutions to real-world problems. Challenges are inevitable, but a true programmer embraces them as stepping stones to growth. Debugging is an exercise in patience, a relentless pursuit of perfection. Collaboration and teamwork amplify the impact of individual brilliance. The power to build tools that empower others is both humbling and empowering. Continuous learning is the key to staying relevant in this ever-evolving landscape. As programmers, we hold the ability to inspire, to improve lives, and to shape the future. So, let us code with purpose and passion, for our creations have the potential to change the world."
# Out:
# 'Programming is an art form of logic and creativity, where lines of code come alive to shape the digital world we inhabit. It requires dedication, discipline, and a thirst for knowledge. Every keystroke is a brushstroke, meticulously crafting intricate solutions to real-world problems. Challenges are inevitable, but a true programmer embraces them as stepping stones to growth. Debugging is an exercise in patience, a relentless pursuit of perfection. Collaboration and teamwork amplify the impact of individual brilliance. The power to build tools that empower others is both humbling and empowering. Continuous learning is the key to staying relevant in this ever-evolving landscape. As programmers, we hold the ability to inspire, to improve lives, and to shape the future. So, let us code with purpose and passion, for our creations have the potential to change the world.'

# %%
# !python tortoise/do_tts.py --text "नमस्कार क्या हालचाल हैं" --voice random --preset fast
# Out:
# ...
# 100% (25193729 of 25193729) |#############| Elapsed Time: 0:00:00 Time:  0:00:00
# Done.
# ...
# 100% (100715777 of 100715777) |###########| Elapsed Time: 0:00:00 Time:  0:00:00
# Done.
# Generating autoregressive samples..
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:204: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# 100% 96/96 [16:00<00:00, 10.00s/it]
# Computing best candidates using CLVP
# 100% 96/96 [06:58<00:00,  4.36s/it]
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:204: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# Transforming autoregressive outputs into audio..
# 100% 80/80 [04:24<00:00,  3.30s/it]
# 100% 80/80 [05:01<00:00,  3.77s/it]
# ...
